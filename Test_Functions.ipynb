# %%
from puzzle_creation import crop_to_square_center, split_image_into_grid_pieces, show_all_pieces, reassemble_pieces

orig_pieces, _ = split_image_into_grid_pieces(crop_to_square_center("City_Scape.jpg"), n = 6, randomize=False)
show_all_pieces(orig_pieces)

shuffled_pieces, shuffled_placement_dict = split_image_into_grid_pieces(crop_to_square_center("City_Scape.jpg"), n = 6, randomize=True)
rearrangement_solution = reassemble_pieces(shuffled_pieces, shuffled_placement_dict)
